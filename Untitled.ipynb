# %%
import pandas as pd

# %%
df =pd.read_csv('catalogue-de-messier.csv', sep=';', index_col=False)

# %%
df
# Out:
#        id         ngc                                object_type  \
# 0     M85    NGC 4382                           Galaxy / Galaxie
# 1     M63    NGC 5055                           Galaxy / Galaxie
# 2     M76     NGC 650    Planetary Nebula / Nébuleuse Planétaire
# 3     M80    NGC 6093         Globular Cluster / Amas Globulaire
# 4     M93    NGC 2447                 Open Cluster / Amas Ouvert
# 5     M74     NGC 628                           Galaxy / Galaxie
# 6     M89    NGC 4552                           Galaxy / Galaxie
# 7     M37    NGC 2099                 Open Cluster / Amas Ouvert
# 8     M36    NGC 1960                 Open Cluster / Amas Ouvert
# 9     M48    NGC 2548                 Open Cluster / Amas Ouvert
# 10    M31     NGC 224                           Galaxy / Galaxie
# 11   M104    NGC 4594                           Galaxy / Galaxie
# 12   M105    NGC 3379                           Galaxy / Galaxie
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-1fa5fbd0afbf> in <module>
# ----> 1 pd.to_csv(d)
#
# AttributeError: module 'pandas' has no attribute 'to_csv'
